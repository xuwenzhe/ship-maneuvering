# %% [markdown]
# # NA540 Homework 8 - Estimation of Maneuvering Dynamics
#
# MEMORANDUM
#
# **DATE:** 12/04/2019
#
# **TO:** A.W.Troesch, NA 540 Instructor
#
# **FROM:** Wenzhe Xu, NA 540 Student
#
# **RE:** NA540 Homework 8, Estimation of maneuvering dynamics.
#
#
# ## Executive Summary
#
# This homework is to

# %%
import numpy as np
import matplotlib.pyplot as plt
import json
dt = 0.5

# %% [markdown]
# ## Problem 3

# %%
with open("p3", "r") as read_file:
    p3data = np.array(json.load(read_file))

time = np.arange(p3data.shape[0])*dt

plt.figure()
plt.plot(p3data[:,4], p3data[:,5])
# plt.plot(time, p4data[:,3])

plt.figure()
plt.plot(time, p3data[:,6]*180/np.pi)
# plt.plot(time, p4data[:,3])

# %% [markdown]
# ## Problem 4

# %%
with open("p4", "r") as read_file:
    p4data = np.array(json.load(read_file))

time = np.arange(p4data.shape[0])*dt

plt.figure()
plt.plot(time, p4data[:,6])
plt.plot(time, -p4data[:,3])
